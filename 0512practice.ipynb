# %% [markdown]
# <a href="https://colab.research.google.com/github/thelighterside/Practice/blob/main/0513practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Reading a csv file

import pandas as pd

url = 'https://raw.githubusercontent.com/thelighterside/my_space/refs/heads/main/students.csv'
df = pd.read_csv(url)

df[df["Grade"] == "A"]  # display the data
# Out:
#     Name  Age Grade
# 0  Alice   14     A
# 2  Cindy   13     A

# %%
# Reading a txt file
import pandas as pd

url = "https://raw.githubusercontent.com/thelighterside/my_space/refs/heads/main/students.txt"
df = pd.read_csv(url, delimiter="\t")  # specify tab as delimiter

df.tail(1)
# Out:
#   Name  Age  Grade
# 1       Bob  15  B

# %%
df["Passed"] = df["Grade"].isin(["A", "B"])
df.to_csv("updated_students.csv", index=False)

# %%
from google.colab import files
files.download("updated_students.csv")
